# %%
#Question 1

# a
student_name = "Jennifer" # Name of the student
student_age = 23 # Age of the student
program_of_study = "BSc. Computer Engineering" # Program of study of the student
student_gpa = 3.8 # Student's GPA

# b
print(f"My name is {student_name}, a {student_age} year old girl studying {program_of_study} with GPA of {student_gpa}.")

# %%
# Question 2

# a
your_name = input("Enter your name: ")
your_age = int(input("Enter your age:"))
your_fav_planguage = input("Enter your favourite Programming Language: ")

# b
print(f"I am {your_name}, a {your_age} year old Tech girl with {your_fav_planguage} as my favourite Programming Language.")
