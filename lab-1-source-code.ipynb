# %%
#Question 1

# a
name = "Jennifer" # Name of the student
age = 23 # Age of the student
program_of_study = "BSc. Computer Engineering" # Program of study of the student
gpa = 3.8 # Student's GPA

# b
print(f"My name is {name}, a {age} year old girl studying {program_of_study} with GPA of {gpa}.")
# Out:
# My name is Jennifer, a 23 year old girl studying BSc. Computer Engineering with GPA of 3.8.
